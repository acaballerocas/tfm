# %%
# Importamos desde el fichero .py de la misma carpeta
import ExtendedModelSelection
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\acaba\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\acaba\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\acaba\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...

# %% [markdown]
# ## Importar conjunto de datos de ejemplo

# %%
# Para hacer pruebas, importamos un dataset de la librería imblearn
from imblearn.datasets import fetch_datasets
import pandas as pd
import numpy as np

ecoli = fetch_datasets()['ecoli']

X = pd.DataFrame(ecoli.data)
y = pd.Series(ecoli.target, name='target')

df = pd.concat([y,X], axis=1)

print("Tamaño del dataset")
print(df.shape)
print("")
print("Primeras observaciones del dataset")
print(df.head())
print("")
print("Distribución de clases")
print(y.value_counts())
# Out:
# Tamaño del dataset
# (336, 8)
#
# Primeras observaciones del dataset
#    target     0     1     2    3     4     5     6
# 0      -1  0.49  0.29  0.48  0.5  0.56  0.24  0.35
# 1      -1  0.07  0.40  0.48  0.5  0.54  0.35  0.44
# 2      -1  0.56  0.40  0.48  0.5  0.49  0.37  0.46
# 3      -1  0.59  0.49  0.48  0.5  0.52  0.45  0.36
# 4      -1  0.23  0.32  0.48  0.5  0.55  0.25  0.35
#
# Distribución de clases
# target
# -1    301
#  1     35
# Name: count, dtype: int64

# %% [markdown]
# ## Uso de ExtendedGridSearchCV

# %% [markdown]
# En primer lugar, definimos los parámetros y estrategias que queremos considerar. Como solo es un ejemplo, en este caso no vamos a dividir la muestra en entrenamiento y test, usamos el dataset completo.

# %%
# Importamos las funciones que vamos a utilizar
# Estrategias de imbalance:
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import ADASYN
# Modelo
from sklearn.linear_model import LogisticRegression

# %%
# Definimos los diccionarios y listas de tuplas necesarios:

# Hiperparámetros del modelo
parametros_modelo = {
    'penalty': [None, 'l2'],
    'C': [0.5, 1]
}

# Lista de estrategias para imbalance
estrategias = [
    ('ninguna', None),
    ('SMOTE', SMOTE(random_state=42)),
    ('ADASYN', ADASYN(random_state=42))
]

# Hiperparámetros de las estrategias
parametros_estrategias = {
    'SMOTE__sampling_strategy': [0.3, 0.5, 1],
    'ADASYN__n_neighbors': [3,5]
}

# %% [markdown]
# Hacemos ExtendedGridSearchCV:

# %%
from ExtendedModelSelection import ExtendedGridSearchCV

ExtGridSearch = ExtendedGridSearchCV(
    estimator=LogisticRegression(),
    param_grid=parametros_modelo,
    samplers=estrategias,
    sampler_params=parametros_estrategias,
    cv=3,
    scoring='average_precision'
)

# %%
MejorModelo, MejoresParam, MejorScore = ExtGridSearch.fit(X,y)
# Out:
# c:\Users\acaba\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\acaba\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\acaba\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\acaba\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %% [markdown]
# En este caso, el mejor modelo consiste en:
# - No utilizar ninguna estrategia de sobre/submuestreo
# - Utilizar el modelo de regresión logística con C=0.5 y sin penalizacion.

# %%
print(MejorModelo)
# Out:
# Pipeline(steps=[('ninguna', None),
#                 ('model', LogisticRegression(C=0.5, penalty=None))])

# %%
# Mejores hiperparámetros
print(MejoresParam)
# Out:
# {'model__C': 0.5, 'model__penalty': None}

# %%
# Mejor score obtenido
print(MejorScore)
# Out:
# 0.7383193301202834
